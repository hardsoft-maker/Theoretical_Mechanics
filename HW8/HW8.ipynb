# %% [markdown]
# <a href="https://colab.research.google.com/github/hardsoft-maker/Theoretical_Mechanics/blob/main/HW8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Task 1
# 1/

# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
from math import sin, cos, tan, sqrt, asin, acos,pi, exp
import matplotlib.pyplot as plt
m_a = 1
m_b = 3
m_d = 20
R_b = 20
R_d = 20
i_bx = 18
fk = 64
r_b = 16
phi = 0.6
g = 9.8
ground_height = 10

# %%
v_a = []
s_all = []
for i in range(0,ground_height):
  s = ground_height - i
  s_all.append(s)
  v_a_2 = (m_a*s + m_d*g*((fk+R_b-sqrt(fk**2 - R_b**2))))
  v_a_2 /= (0.5*m_a+0.5*m_b*i_bx/r_b**2 + 0.5*m_d*R_b**2/r_b**2 + 0.25*m_d*R_b**2/((R_d**2)*(r_b**2)))
  v_a.append(sqrt(v_a_2))
plt.plot(s_all,v_a, label="v_A(s)")
plt.legend()
plt.show()

# %% [markdown]
#  2/

# %% [markdown]
# if we do consider the masses of links FK, KC and the piston K, we would have forces in the center of masses of the piston which in turn require considering the pressure on the surface of the slider. this will lead to having several equations that cannot be solved since the number of unknowns will be more than the number of equations themselves

# %% [markdown]
# # TASK 2
